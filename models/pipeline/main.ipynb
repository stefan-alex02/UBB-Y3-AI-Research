# %%
# Load logger

from logger import create_logger
logger = create_logger()

# Define configurations
from utils import load_config
config = load_config("config.yaml")

# Load datasets
from datasets import load_datasets
train_loader, val_loader, test_loader, _ = load_datasets(config, logger)
# Out:
# 02:05:39 | Dataset: mini-GCD-split
# 02:05:39 | Dataset: mini-GCD-split
# 02:05:39 | Dataset: mini-GCD-split
# 02:05:40 | Training class counts:
# 02:05:40 | Training class counts:
# 02:05:40 | Training class counts:
# 02:05:40 | 1_cumulus: 49
# 02:05:40 | 1_cumulus: 49
# 02:05:40 | 1_cumulus: 49
# 02:05:40 | 2_altocumulus: 49
# 02:05:40 | 2_altocumulus: 49
# 02:05:40 | 2_altocumulus: 49
# 02:05:40 | 3_cirrus: 49
# 02:05:40 | 3_cirrus: 49
# 02:05:40 | 3_cirrus: 49
# 02:05:40 | 4_clearsky: 49
# 02:05:40 | 4_clearsky: 49
# 02:05:40 | 4_clearsky: 49
# 02:05:40 | 5_stratocumulus: 49
# 02:05:40 | 5_stratocumulus: 49
# 02:05:40 | 5_stratocumulus: 49
# 02:05:40 | 6_cumulonimbus: 49
# 02:05:40 | 6_cumulonimbus: 49
# 02:05:40 | 6_cumulonimbus: 49
# 02:05:40 | 7_mixed: 49
# 02:05:40 | 7_mixed: 49
# 02:05:40 | 7_mixed: 49
# 02:05:40 | Number of training samples: 343
# 02:05:40 | Number of training samples: 343
# 02:05:40 | Number of training samples: 343
